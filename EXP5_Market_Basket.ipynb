# %%
#install apyori module for product selling using Groceries_dataset
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5956 sha256=e964bd4cc75dd1258e35cf89020dce484527f9827d4a1f6825959e8d950ffd10
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
#importing libraries
import numpy as np
import pandas as pd

from apyori import apriori

# %%
data=pd.read_csv("/content/Groceries_dataset.csv",names=["itemDescription"],header=None)

# %%
data
# Out:
#                                 itemDescription
# Member_number Date              itemDescription
# 1808          21-07-2015         tropical fruit
# 2552          05-01-2015             whole milk
# 2300          19-09-2015              pip fruit
# 1187          12-12-2015       other vegetables
# ...                                         ...
# 4471          08-10-2014          sliced cheese
# 2022          23-02-2014                  candy
# 1097          16-04-2014               cake bar
# 1510          03-12-2014  fruit/vegetable juice
# 1521          26-12-2014               cat food
#
# [38766 rows x 1 columns]

# %%
data.values
# Out:
# array([['itemDescription'],
#        ['tropical fruit'],
#        ['whole milk'],
#        ...,
#        ['cake bar'],
#        ['fruit/vegetable juice'],
#        ['cat food']], dtype=object)

# %%
data1=list(data["itemDescription"].apply(lambda x:x.split(',')))

# %%
data1
# Out:
# [['itemDescription'],
#  ['tropical fruit'],
#  ['whole milk'],
#  ['pip fruit'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['other vegetables'],
#  ['pot plants'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['citrus fruit'],
#  ['beef'],
#  ['frankfurter'],
#  ['chicken'],
#  ['butter'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter milk'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['tropical fruit'],
#  ['bottled water'],
#  ['yogurt'],
#  ['sausage'],
#  ['other vegetables'],
#  ['brown bread'],
#  ['yogurt'],
#  ['hamburger meat'],
#  ['root vegetables'],
#  ['pork'],
#  ['beef'],
#  ['pastry'],
#  ['fruit/vegetable juice'],
#  ['canned beer'],
#  ['root vegetables'],
#  ['citrus fruit'],
#  ['sausage'],
#  ['tropical fruit'],
#  ['berries'],
#  ['canned beer'],
#  ['butter milk'],
#  ['coffee'],
#  ['pastry'],
#  ['rolls/buns'],
#  ['misc. beverages'],
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
te=TransactionEncoder()
te_data=te.fit(data1).transform(data1)
df=pd.DataFrame(te_data,columns=te.columns_)
df
# Out:
#        Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                      False     False             False             False
# 1                      False     False             False             False
# 2                      False     False             False             False
# 3                      False     False             False             False
# 4                      False     False             False             False
# ...                      ...       ...               ...               ...
# 38761                  False     False             False             False
# 38762                  False     False             False             False
# 38763                  False     False             False             False
# 38764                  False     False             False             False
# 38765                  False     False             False             False
#
# ...

# %%
#importing the apriori library
from mlxtend.frequent_patterns import apriori

# %%
df1=apriori(df,min_support=0.01,use_colnames=True)
df1
# Out:
#      support                 itemsets
# 0   0.013311                   (beef)
# 1   0.017722           (bottled beer)
# 2   0.024067          (bottled water)
# 3   0.014729            (brown bread)
# 4   0.013775                 (butter)
# 5   0.018496            (canned beer)
# 6   0.010886                (chicken)
# 7   0.020946           (citrus fruit)
# 8   0.012279                 (coffee)
# 9   0.013259                   (curd)
# 10  0.014600          (domestic eggs)
# 11  0.014962            (frankfurter)
# 12  0.010963      (frozen vegetables)
# 13  0.013362  (fruit/vegetable juice)
# 14  0.012666              (margarine)
# 15  0.015374             (newspapers)
# 16  0.048960       (other vegetables)
# 17  0.020250                 (pastry)
# 18  0.019192              (pip fruit)
# 19  0.014600                   (pork)
# 20  0.044266             (rolls/buns)
# 21  0.027627        (root vegetables)
# 22  0.023835                (sausage)
# 23  0.018857          (shopping bags)
# ...

# %%
df1.sort_values(by="support",ascending=False)
# Out:
#      support                 itemsets
# 27  0.064541             (whole milk)
# 16  0.048960       (other vegetables)
# 20  0.044266             (rolls/buns)
# 24  0.039055                   (soda)
# 28  0.034412                 (yogurt)
# 21  0.027627        (root vegetables)
# 25  0.026621         (tropical fruit)
# 2   0.024067          (bottled water)
# 22  0.023835                (sausage)
# 7   0.020946           (citrus fruit)
# 17  0.020250                 (pastry)
# 18  0.019192              (pip fruit)
# 23  0.018857          (shopping bags)
# 5   0.018496            (canned beer)
# 1   0.017722           (bottled beer)
# 26  0.017077     (whipped/sour cream)
# 15  0.015374             (newspapers)
# 11  0.014962            (frankfurter)
# 3   0.014729            (brown bread)
# 10  0.014600          (domestic eggs)
# 19  0.014600                   (pork)
# 4   0.013775                 (butter)
# 13  0.013362  (fruit/vegetable juice)
# 0   0.013311                   (beef)
# ...

# %%
df1["length"]=df1["itemsets"].apply(lambda x:len(x))
df1
# Out:
#      support                 itemsets  length
# 0   0.013311                   (beef)       1
# 1   0.017722           (bottled beer)       1
# 2   0.024067          (bottled water)       1
# 3   0.014729            (brown bread)       1
# 4   0.013775                 (butter)       1
# 5   0.018496            (canned beer)       1
# 6   0.010886                (chicken)       1
# 7   0.020946           (citrus fruit)       1
# 8   0.012279                 (coffee)       1
# 9   0.013259                   (curd)       1
# 10  0.014600          (domestic eggs)       1
# 11  0.014962            (frankfurter)       1
# 12  0.010963      (frozen vegetables)       1
# 13  0.013362  (fruit/vegetable juice)       1
# 14  0.012666              (margarine)       1
# 15  0.015374             (newspapers)       1
# 16  0.048960       (other vegetables)       1
# 17  0.020250                 (pastry)       1
# 18  0.019192              (pip fruit)       1
# ...

# %%
df1[(df1["length"]==1) & (df1["support"]>0.05)]
# Out:
#      support      itemsets  length
# 27  0.064541  (whole milk)       1
